# %%
import os
import pickle

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras import models
# import pandas as pd

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# RTX On
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
def load_data(file):
    with open(file, 'rb') as fo:
        try:
            samples = pickle.load(fo)
        except UnicodeDecodeError:  # python 3.x
            fo.seek(0)
            samples = pickle.load(fo, encoding='latin1')

    data, labels = samples['data'], samples['labels']

    data = np.array(data, dtype=np.float32) / 255
    labels = np.array(labels, dtype=np.int32)
    return data, labels

# %%
def make_model(num_ch_c1, num_ch_c2, use_dropout):

    model = tf.keras.Sequential()
    
    if (use_dropout == False):
        # Input Layer
        model.add(layers.Input(shape=(3072,)))
        model.add(layers.Reshape(target_shape=(32, 32, 3), input_shape=(3072,)))
        # C₁ Convolutional Layer
        model.add(layers.Conv2D(num_ch_c1, 9, padding='valid', activation='relu', input_shape=(None, None, 3)))
        # S₁ Max Pooling Layer
        model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2), padding='valid'))
        # C₂ Convolutional Layer
        model.add(layers.Conv2D(num_ch_c2, 9, padding='valid', activation='relu', input_shape=(None, None, 3)))
        # S₂ Max Pooling Layer
        model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2), padding='valid'))
        # Flatten
        model.add(layers.Flatten())
        # F₃ Fully-Connected Layer
        model.add(layers.Dense(300, activation=None, use_bias=True, input_shape=(300,)))  # Here no softmax because we have combined it with the loss   
        # F₄ Fully-Connected Layer 
        model.add(layers.Dense(10, activation='softmax', use_bias=True, input_shape=(300,)))  # Here no softmax because we have combined it with the loss
    else:
        # Input Layer
        model.add(layers.Input(shape=(3072,)))
        model.add(layers.Reshape(target_shape=(32, 32, 3), input_shape=(3072,)))
        # C₁ Convolutional Layer
        model.add(layers.Conv2D(num_ch_c1, 9, padding='valid', activation='relu', input_shape=(None, None, 3)))
        # S₁ Max Pooling Layer
        model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2), padding='valid'))
        # C₂ Convolutional Layer
        model.add(layers.Conv2D(num_ch_c2, 9, padding='valid', activation='relu', input_shape=(None, None, 3)))
        # S₂ Max Pooling Layer
        model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2), padding='valid'))
        # Flatten
        model.add(layers.Flatten())
        # F₃ Fully-Connected Layer
        model.add(layers.Dense(300, activation=None, use_bias=True, input_shape=(300,)))  # Here no softmax because we have combined it with the loss   
        # D₁ Dropout Layer
        model.add(layers.Dropout(0.5))
        # F₄ Fully-Connected Layer 
        model.add(layers.Dense(10, activation='softmax', use_bias=True, input_shape=(300,)))  # Here no softmax because we have combined it with the loss
        # D₂ Dropout Layer
        model.add(layers.Dropout(0.5))

    return model

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# Enabled, as we have decided the optimal channel values
num_ch_c1 = 30  # Question 2
num_ch_c2 = 80  # Question 2

epochs = 1000  # Fixed
batch_size = 128  # Fixed
learning_rate = 0.001

optimizer_ = 'RMSprop'  # Question 3
#use_dropout = False  # Question 3(d) (see make_model)

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
if optimizer_ == 'SGD':
    optimizer = keras.optimizers.SGD(learning_rate=learning_rate)
elif optimizer_ == 'SGD-momentum':  # Question 3(a)
    momentum = 0.1
    optimizer = keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum)
elif optimizer_ == 'RMSprop':  # Question 3(b)
    optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)
elif optimizer_ == 'Adam':  # Question 3(c)
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
else:
    raise NotImplementedError(f'You do not need to handle [{optimizer_}] in this project.')

# %%
'''
Load Training and Test Datasets
'''
x_train, y_train = load_data('/content/gdrive/My Drive/Colab Notebooks/data_batch_1')
x_test, y_test = load_data('/content/gdrive/My Drive/Colab Notebooks/test_batch_trim')

# %%
# Create folder to store one more level down
if not os.path.exists(f'/content/gdrive/My Drive/Colab Output/models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout'):
    os.mkdir(f'/content/gdrive/My Drive/Colab Output/models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout')
if not os.path.exists(f'/content/gdrive/My Drive/Colab Output/models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout'):
    os.mkdir(f'/content/gdrive/My Drive/Colab Output/models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout')

# %%
# Set Question Variable for file purposes
question = 'q3b'

# %%
'''
Train Model for both without and with dropout
'''
# Optimal Values Chosen, c1 = 30, c2 = 80
dropout_list = [True, False]

for each in dropout_list:

    use_dropout = each
    model = make_model(num_ch_c1, num_ch_c2, use_dropout) 

    # Train RMSprop
    model.compile(optimizer=optimizer, loss=loss, metrics='accuracy')
    history = model.fit(
        x_train,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_test, y_test))

    # Extract Loss Values
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    # Extract Accuracy Values
    train_acc = history.history['accuracy']
    test_acc = history.history['val_accuracy']

    # Save instanced variables to list
    instanced_variables = [train_loss, val_loss, train_acc, test_acc]

    # Save model
    if use_dropout:
        model.save(f'/content/gdrive/My Drive/Colab Output/models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout')
        filename = f'/content/gdrive/My Drive/Colab Output/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_variables'
        outfile = open(filename,'wb')
        pickle.dump(instanced_variables, outfile)
        outfile.close()    
    else:
        model.save(f'/content/gdrive/My Drive/Colab Output/models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout')
        filename = f'/content/gdrive/My Drive/Colab Output/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_variables'
        outfile = open(filename,'wb')
        pickle.dump(instanced_variables, outfile)
        outfile.close()
# Out:
# Epoch 1/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2787 - accuracy: 0.1485 - val_loss: 2.2258 - val_accuracy: 0.2265
# Epoch 2/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2329 - accuracy: 0.1987 - val_loss: 2.2115 - val_accuracy: 0.2345
# Epoch 3/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1951 - accuracy: 0.2233 - val_loss: 2.1411 - val_accuracy: 0.3170
# Epoch 4/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1784 - accuracy: 0.2335 - val_loss: 2.2185 - val_accuracy: 0.2255
# Epoch 5/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1760 - accuracy: 0.2332 - val_loss: 2.1675 - val_accuracy: 0.2760
# Epoch 6/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1621 - accuracy: 0.2420 - val_loss: 2.1132 - val_accuracy: 0.3430
# Epoch 7/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1446 - accuracy: 0.2565 - val_loss: 2.1386 - val_accuracy: 0.3110
# Epoch 8/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1290 - accuracy: 0.2656 - val_loss: 2.0887 - val_accuracy: 0.3680
# Epoch 9/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1224 - accuracy: 0.2675 - val_loss: 2.0889 - val_accuracy: 0.3665
# Epoch 10/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1150 - accuracy: 0.2726 - val_loss: 2.1123 - val_accuracy: 0.3330
# Epoch 11/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.1098 - accuracy: 0.2746 - val_loss: 2.0634 - val_accuracy: 0.3940
# Epoch 12/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0903 - accuracy: 0.2840 - val_loss: 2.0702 - val_accuracy: 0.3910
# Epoch 13/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0946 - accuracy: 0.2860 - val_loss: 2.0960 - val_accuracy: 0.3620
# Epoch 14/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0920 - accuracy: 0.2833 - val_loss: 2.0500 - val_accuracy: 0.4095
# Epoch 15/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0794 - accuracy: 0.2874 - val_loss: 2.1179 - val_accuracy: 0.3310
# Epoch 16/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0747 - accuracy: 0.2904 - val_loss: 2.0400 - val_accuracy: 0.4145
# Epoch 17/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0679 - accuracy: 0.2934 - val_loss: 2.0088 - val_accuracy: 0.4540
# Epoch 18/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0441 - accuracy: 0.3094 - val_loss: 2.0789 - val_accuracy: 0.3825
# Epoch 19/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0401 - accuracy: 0.3101 - val_loss: 2.0158 - val_accuracy: 0.4395
# Epoch 20/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0388 - accuracy: 0.3078 - val_loss: 1.9965 - val_accuracy: 0.4685
# Epoch 21/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0355 - accuracy: 0.3054 - val_loss: 2.0443 - val_accuracy: 0.4105
# Epoch 22/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0218 - accuracy: 0.3183 - val_loss: 2.0205 - val_accuracy: 0.4400
# Epoch 23/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0188 - accuracy: 0.3157 - val_loss: 2.0363 - val_accuracy: 0.4215
# Epoch 24/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0019 - accuracy: 0.3269 - val_loss: 2.0059 - val_accuracy: 0.4565
# Epoch 25/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0122 - accuracy: 0.3176 - val_loss: 2.0289 - val_accuracy: 0.4275
# Epoch 26/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0049 - accuracy: 0.3236 - val_loss: 2.0305 - val_accuracy: 0.4230
# Epoch 27/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0003 - accuracy: 0.3255 - val_loss: 2.0243 - val_accuracy: 0.4315
# Epoch 28/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9940 - accuracy: 0.3255 - val_loss: 2.0274 - val_accuracy: 0.4305
# Epoch 29/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9933 - accuracy: 0.3263 - val_loss: 2.0443 - val_accuracy: 0.4075
# Epoch 30/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9877 - accuracy: 0.3271 - val_loss: 2.0177 - val_accuracy: 0.4430
# Epoch 31/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9796 - accuracy: 0.3301 - val_loss: 2.0471 - val_accuracy: 0.4075
# Epoch 32/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9668 - accuracy: 0.3398 - val_loss: 2.0305 - val_accuracy: 0.4290
# Epoch 33/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9754 - accuracy: 0.3341 - val_loss: 2.0743 - val_accuracy: 0.3805
# Epoch 34/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9584 - accuracy: 0.3429 - val_loss: 1.9960 - val_accuracy: 0.4615
# Epoch 35/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9579 - accuracy: 0.3440 - val_loss: 2.0601 - val_accuracy: 0.4005
# Epoch 36/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9667 - accuracy: 0.3345 - val_loss: 2.0009 - val_accuracy: 0.4550
# Epoch 37/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9553 - accuracy: 0.3397 - val_loss: 2.0191 - val_accuracy: 0.4385
# Epoch 38/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9333 - accuracy: 0.3586 - val_loss: 1.9947 - val_accuracy: 0.4590
# Epoch 39/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9354 - accuracy: 0.3511 - val_loss: 2.0393 - val_accuracy: 0.4155
# Epoch 40/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9342 - accuracy: 0.3524 - val_loss: 2.0324 - val_accuracy: 0.4240
# Epoch 41/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9340 - accuracy: 0.3549 - val_loss: 2.0493 - val_accuracy: 0.4080
# Epoch 42/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9268 - accuracy: 0.3572 - val_loss: 1.9700 - val_accuracy: 0.4845
# Epoch 43/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9316 - accuracy: 0.3517 - val_loss: 1.9778 - val_accuracy: 0.4730
# Epoch 44/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9259 - accuracy: 0.3531 - val_loss: 1.9983 - val_accuracy: 0.4565
# Epoch 45/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9108 - accuracy: 0.3644 - val_loss: 2.0105 - val_accuracy: 0.4460
# Epoch 46/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9100 - accuracy: 0.3598 - val_loss: 1.9941 - val_accuracy: 0.4595
# Epoch 47/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9089 - accuracy: 0.3603 - val_loss: 2.0245 - val_accuracy: 0.4355
# Epoch 48/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9025 - accuracy: 0.3668 - val_loss: 1.9755 - val_accuracy: 0.4830
# Epoch 49/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8958 - accuracy: 0.3675 - val_loss: 1.9777 - val_accuracy: 0.4790
# Epoch 50/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8973 - accuracy: 0.3655 - val_loss: 1.9968 - val_accuracy: 0.4655
# Epoch 51/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9028 - accuracy: 0.3620 - val_loss: 1.9790 - val_accuracy: 0.4770
# Epoch 52/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8973 - accuracy: 0.3657 - val_loss: 1.9634 - val_accuracy: 0.4960
# Epoch 53/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8953 - accuracy: 0.3642 - val_loss: 1.9909 - val_accuracy: 0.4655
# Epoch 54/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8851 - accuracy: 0.3681 - val_loss: 2.0326 - val_accuracy: 0.4200
# Epoch 55/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8803 - accuracy: 0.3709 - val_loss: 1.9553 - val_accuracy: 0.5000
# Epoch 56/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8826 - accuracy: 0.3671 - val_loss: 1.9750 - val_accuracy: 0.4785
# Epoch 57/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8826 - accuracy: 0.3647 - val_loss: 1.9685 - val_accuracy: 0.4905
# Epoch 58/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8813 - accuracy: 0.3692 - val_loss: 1.9678 - val_accuracy: 0.4885
# Epoch 59/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8574 - accuracy: 0.3820 - val_loss: 1.9983 - val_accuracy: 0.4595
# Epoch 60/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8668 - accuracy: 0.3776 - val_loss: 1.9611 - val_accuracy: 0.4950
# Epoch 61/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8785 - accuracy: 0.3683 - val_loss: 1.9843 - val_accuracy: 0.4725
# Epoch 62/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8643 - accuracy: 0.3745 - val_loss: 1.9753 - val_accuracy: 0.4850
# Epoch 63/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8477 - accuracy: 0.3834 - val_loss: 1.9886 - val_accuracy: 0.4670
# Epoch 64/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8509 - accuracy: 0.3837 - val_loss: 1.9756 - val_accuracy: 0.4815
# Epoch 65/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8474 - accuracy: 0.3840 - val_loss: 1.9610 - val_accuracy: 0.5005
# Epoch 66/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8453 - accuracy: 0.3894 - val_loss: 1.9819 - val_accuracy: 0.4725
# Epoch 67/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8490 - accuracy: 0.3839 - val_loss: 1.9705 - val_accuracy: 0.4895
# Epoch 68/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8517 - accuracy: 0.3815 - val_loss: 1.9657 - val_accuracy: 0.4935
# Epoch 69/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8473 - accuracy: 0.3859 - val_loss: 1.9657 - val_accuracy: 0.4920
# Epoch 70/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8439 - accuracy: 0.3837 - val_loss: 1.9879 - val_accuracy: 0.4700
# Epoch 71/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8509 - accuracy: 0.3800 - val_loss: 1.9695 - val_accuracy: 0.4825
# Epoch 72/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8510 - accuracy: 0.3779 - val_loss: 1.9756 - val_accuracy: 0.4815
# Epoch 73/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8274 - accuracy: 0.3945 - val_loss: 1.9892 - val_accuracy: 0.4625
# Epoch 74/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8285 - accuracy: 0.3940 - val_loss: 2.0104 - val_accuracy: 0.4435
# Epoch 75/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8307 - accuracy: 0.3878 - val_loss: 1.9877 - val_accuracy: 0.4700
# Epoch 76/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8232 - accuracy: 0.3971 - val_loss: 1.9980 - val_accuracy: 0.4565
# Epoch 77/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8308 - accuracy: 0.3907 - val_loss: 1.9899 - val_accuracy: 0.4690
# Epoch 78/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8211 - accuracy: 0.3961 - val_loss: 1.9801 - val_accuracy: 0.4755
# Epoch 79/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8355 - accuracy: 0.3863 - val_loss: 1.9909 - val_accuracy: 0.4675
# Epoch 80/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8231 - accuracy: 0.3943 - val_loss: 2.0098 - val_accuracy: 0.4480
# Epoch 81/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8336 - accuracy: 0.3852 - val_loss: 1.9715 - val_accuracy: 0.4865
# Epoch 82/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8088 - accuracy: 0.4038 - val_loss: 1.9930 - val_accuracy: 0.4660
# Epoch 83/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8260 - accuracy: 0.3893 - val_loss: 1.9891 - val_accuracy: 0.4670
# Epoch 84/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8231 - accuracy: 0.3900 - val_loss: 1.9949 - val_accuracy: 0.4635
# Epoch 85/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8147 - accuracy: 0.3967 - val_loss: 2.0069 - val_accuracy: 0.4490
# Epoch 86/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8125 - accuracy: 0.3986 - val_loss: 2.0249 - val_accuracy: 0.4335
# Epoch 87/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8013 - accuracy: 0.4044 - val_loss: 1.9667 - val_accuracy: 0.4935
# Epoch 88/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8203 - accuracy: 0.3938 - val_loss: 1.9582 - val_accuracy: 0.5030
# Epoch 89/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8166 - accuracy: 0.3971 - val_loss: 1.9676 - val_accuracy: 0.4915
# Epoch 90/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8103 - accuracy: 0.3980 - val_loss: 1.9973 - val_accuracy: 0.4610
# Epoch 91/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8024 - accuracy: 0.4029 - val_loss: 1.9853 - val_accuracy: 0.4700
# Epoch 92/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8149 - accuracy: 0.3965 - val_loss: 1.9851 - val_accuracy: 0.4740
# Epoch 93/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8145 - accuracy: 0.3933 - val_loss: 1.9696 - val_accuracy: 0.4855
# Epoch 94/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8005 - accuracy: 0.4026 - val_loss: 1.9918 - val_accuracy: 0.4645
# Epoch 95/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7942 - accuracy: 0.4060 - val_loss: 1.9916 - val_accuracy: 0.4635
# Epoch 96/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8095 - accuracy: 0.4008 - val_loss: 1.9678 - val_accuracy: 0.4915
# Epoch 97/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7980 - accuracy: 0.4040 - val_loss: 1.9771 - val_accuracy: 0.4805
# Epoch 98/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7803 - accuracy: 0.4148 - val_loss: 1.9779 - val_accuracy: 0.4770
# Epoch 99/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8120 - accuracy: 0.3973 - val_loss: 1.9854 - val_accuracy: 0.4705
# Epoch 100/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8104 - accuracy: 0.4004 - val_loss: 1.9810 - val_accuracy: 0.4790
# Epoch 101/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8007 - accuracy: 0.3999 - val_loss: 1.9866 - val_accuracy: 0.4735
# Epoch 102/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7869 - accuracy: 0.4079 - val_loss: 1.9960 - val_accuracy: 0.4620
# Epoch 103/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7964 - accuracy: 0.4018 - val_loss: 1.9772 - val_accuracy: 0.4790
# Epoch 104/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7915 - accuracy: 0.4076 - val_loss: 1.9730 - val_accuracy: 0.4825
# Epoch 105/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.8010 - accuracy: 0.4011 - val_loss: 1.9818 - val_accuracy: 0.4740
# Epoch 106/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7907 - accuracy: 0.4095 - val_loss: 1.9714 - val_accuracy: 0.4880
# Epoch 107/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7869 - accuracy: 0.4094 - val_loss: 2.0075 - val_accuracy: 0.4505
# Epoch 108/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7834 - accuracy: 0.4080 - val_loss: 2.0001 - val_accuracy: 0.4575
# Epoch 109/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7773 - accuracy: 0.4166 - val_loss: 1.9771 - val_accuracy: 0.4810
# Epoch 110/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7872 - accuracy: 0.4099 - val_loss: 1.9671 - val_accuracy: 0.4920
# Epoch 111/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7794 - accuracy: 0.4158 - val_loss: 1.9644 - val_accuracy: 0.4925
# Epoch 112/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7880 - accuracy: 0.4075 - val_loss: 1.9962 - val_accuracy: 0.4605
# Epoch 113/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7894 - accuracy: 0.4081 - val_loss: 1.9955 - val_accuracy: 0.4635
# Epoch 114/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7841 - accuracy: 0.4106 - val_loss: 1.9812 - val_accuracy: 0.4725
# Epoch 115/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7847 - accuracy: 0.4094 - val_loss: 1.9905 - val_accuracy: 0.4660
# Epoch 116/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7912 - accuracy: 0.4071 - val_loss: 1.9887 - val_accuracy: 0.4710
# Epoch 117/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7678 - accuracy: 0.4209 - val_loss: 1.9656 - val_accuracy: 0.4945
# Epoch 118/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7898 - accuracy: 0.4067 - val_loss: 1.9700 - val_accuracy: 0.4905
# Epoch 119/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7816 - accuracy: 0.4139 - val_loss: 1.9745 - val_accuracy: 0.4825
# Epoch 120/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7808 - accuracy: 0.4101 - val_loss: 1.9812 - val_accuracy: 0.4760
# Epoch 121/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7732 - accuracy: 0.4142 - val_loss: 1.9901 - val_accuracy: 0.4675
# Epoch 122/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7857 - accuracy: 0.4126 - val_loss: 1.9923 - val_accuracy: 0.4690
# Epoch 123/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8016 - accuracy: 0.4018 - val_loss: 1.9913 - val_accuracy: 0.4655
# Epoch 124/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7775 - accuracy: 0.4134 - val_loss: 1.9705 - val_accuracy: 0.4870
# Epoch 125/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7768 - accuracy: 0.4178 - val_loss: 1.9685 - val_accuracy: 0.4910
# Epoch 126/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7741 - accuracy: 0.4163 - val_loss: 1.9871 - val_accuracy: 0.4720
# Epoch 127/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7766 - accuracy: 0.4132 - val_loss: 1.9876 - val_accuracy: 0.4705
# Epoch 128/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7869 - accuracy: 0.4097 - val_loss: 1.9728 - val_accuracy: 0.4880
# Epoch 129/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7690 - accuracy: 0.4178 - val_loss: 1.9669 - val_accuracy: 0.4925
# Epoch 130/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7688 - accuracy: 0.4167 - val_loss: 1.9964 - val_accuracy: 0.4625
# Epoch 131/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7863 - accuracy: 0.4080 - val_loss: 1.9914 - val_accuracy: 0.4640
# Epoch 132/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.7646 - accuracy: 0.4196 - val_loss: 2.0084 - val_accuracy: 0.4495
# Epoch 133/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7720 - accuracy: 0.4158 - val_loss: 2.0008 - val_accuracy: 0.4560
# Epoch 134/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7761 - accuracy: 0.4133 - val_loss: 1.9638 - val_accuracy: 0.4955
# Epoch 135/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7737 - accuracy: 0.4153 - val_loss: 1.9847 - val_accuracy: 0.4730
# Epoch 136/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7694 - accuracy: 0.4192 - val_loss: 1.9808 - val_accuracy: 0.4765
# Epoch 137/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7867 - accuracy: 0.4116 - val_loss: 1.9844 - val_accuracy: 0.4715
# Epoch 138/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7711 - accuracy: 0.4141 - val_loss: 1.9703 - val_accuracy: 0.4890
# Epoch 139/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7591 - accuracy: 0.4235 - val_loss: 1.9842 - val_accuracy: 0.4730
# Epoch 140/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7645 - accuracy: 0.4230 - val_loss: 1.9797 - val_accuracy: 0.4785
# Epoch 141/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7741 - accuracy: 0.4156 - val_loss: 1.9694 - val_accuracy: 0.4915
# Epoch 142/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7826 - accuracy: 0.4140 - val_loss: 1.9714 - val_accuracy: 0.4865
# Epoch 143/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7794 - accuracy: 0.4177 - val_loss: 1.9911 - val_accuracy: 0.4670
# Epoch 144/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7807 - accuracy: 0.4108 - val_loss: 1.9774 - val_accuracy: 0.4820
# Epoch 145/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7647 - accuracy: 0.4216 - val_loss: 1.9807 - val_accuracy: 0.4765
# Epoch 146/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7640 - accuracy: 0.4186 - val_loss: 1.9914 - val_accuracy: 0.4640
# Epoch 147/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7592 - accuracy: 0.4262 - val_loss: 1.9834 - val_accuracy: 0.4760
# Epoch 148/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7691 - accuracy: 0.4208 - val_loss: 1.9809 - val_accuracy: 0.4795
# Epoch 149/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7785 - accuracy: 0.4133 - val_loss: 1.9836 - val_accuracy: 0.4735
# Epoch 150/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7597 - accuracy: 0.4250 - val_loss: 1.9698 - val_accuracy: 0.4910
# Epoch 151/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7755 - accuracy: 0.4158 - val_loss: 1.9902 - val_accuracy: 0.4660
# Epoch 152/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7686 - accuracy: 0.4241 - val_loss: 1.9640 - val_accuracy: 0.4955
# Epoch 153/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7741 - accuracy: 0.4154 - val_loss: 2.0270 - val_accuracy: 0.4335
# Epoch 154/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7765 - accuracy: 0.4163 - val_loss: 1.9749 - val_accuracy: 0.4860
# Epoch 155/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7693 - accuracy: 0.4198 - val_loss: 1.9917 - val_accuracy: 0.4655
# Epoch 156/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7572 - accuracy: 0.4260 - val_loss: 1.9750 - val_accuracy: 0.4820
# Epoch 157/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7660 - accuracy: 0.4230 - val_loss: 1.9706 - val_accuracy: 0.4895
# Epoch 158/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7756 - accuracy: 0.4173 - val_loss: 1.9891 - val_accuracy: 0.4695
# Epoch 159/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7693 - accuracy: 0.4154 - val_loss: 1.9786 - val_accuracy: 0.4765
# Epoch 160/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7658 - accuracy: 0.4238 - val_loss: 1.9811 - val_accuracy: 0.4775
# Epoch 161/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7667 - accuracy: 0.4249 - val_loss: 1.9727 - val_accuracy: 0.4870
# Epoch 162/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7706 - accuracy: 0.4255 - val_loss: 1.9840 - val_accuracy: 0.4755
# Epoch 163/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7653 - accuracy: 0.4238 - val_loss: 1.9821 - val_accuracy: 0.4735
# Epoch 164/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7711 - accuracy: 0.4201 - val_loss: 1.9846 - val_accuracy: 0.4750
# Epoch 165/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7652 - accuracy: 0.4209 - val_loss: 1.9746 - val_accuracy: 0.4840
# Epoch 166/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7620 - accuracy: 0.4210 - val_loss: 1.9792 - val_accuracy: 0.4790
# Epoch 167/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7743 - accuracy: 0.4150 - val_loss: 1.9610 - val_accuracy: 0.4975
# Epoch 168/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7662 - accuracy: 0.4199 - val_loss: 1.9978 - val_accuracy: 0.4580
# Epoch 169/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7530 - accuracy: 0.4319 - val_loss: 1.9700 - val_accuracy: 0.4885
# Epoch 170/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7646 - accuracy: 0.4252 - val_loss: 1.9822 - val_accuracy: 0.4770
# Epoch 171/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7725 - accuracy: 0.4195 - val_loss: 1.9766 - val_accuracy: 0.4820
# Epoch 172/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7678 - accuracy: 0.4249 - val_loss: 1.9849 - val_accuracy: 0.4755
# Epoch 173/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7726 - accuracy: 0.4234 - val_loss: 1.9575 - val_accuracy: 0.5015
# Epoch 174/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7608 - accuracy: 0.4276 - val_loss: 1.9719 - val_accuracy: 0.4855
# Epoch 175/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7754 - accuracy: 0.4171 - val_loss: 1.9763 - val_accuracy: 0.4820
# Epoch 176/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7735 - accuracy: 0.4218 - val_loss: 1.9757 - val_accuracy: 0.4835
# Epoch 177/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7772 - accuracy: 0.4164 - val_loss: 1.9956 - val_accuracy: 0.4650
# Epoch 178/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7601 - accuracy: 0.4270 - val_loss: 1.9688 - val_accuracy: 0.4905
# Epoch 179/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7714 - accuracy: 0.4256 - val_loss: 1.9729 - val_accuracy: 0.4865
# Epoch 180/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7711 - accuracy: 0.4219 - val_loss: 1.9816 - val_accuracy: 0.4780
# Epoch 181/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7650 - accuracy: 0.4246 - val_loss: 1.9856 - val_accuracy: 0.4745
# Epoch 182/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7671 - accuracy: 0.4301 - val_loss: 2.0136 - val_accuracy: 0.4475
# Epoch 183/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7718 - accuracy: 0.4262 - val_loss: 1.9744 - val_accuracy: 0.4830
# Epoch 184/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7502 - accuracy: 0.4347 - val_loss: 1.9722 - val_accuracy: 0.4870
# Epoch 185/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7626 - accuracy: 0.4225 - val_loss: 1.9966 - val_accuracy: 0.4625
# Epoch 186/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7610 - accuracy: 0.4269 - val_loss: 1.9757 - val_accuracy: 0.4845
# Epoch 187/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7587 - accuracy: 0.4308 - val_loss: 1.9824 - val_accuracy: 0.4795
# Epoch 188/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7622 - accuracy: 0.4338 - val_loss: 1.9932 - val_accuracy: 0.4670
# Epoch 189/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7650 - accuracy: 0.4294 - val_loss: 1.9904 - val_accuracy: 0.4700
# Epoch 190/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7617 - accuracy: 0.4312 - val_loss: 1.9713 - val_accuracy: 0.4895
# Epoch 191/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7464 - accuracy: 0.4350 - val_loss: 1.9860 - val_accuracy: 0.4710
# Epoch 192/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7501 - accuracy: 0.4338 - val_loss: 1.9757 - val_accuracy: 0.4845
# Epoch 193/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7487 - accuracy: 0.4341 - val_loss: 2.0231 - val_accuracy: 0.4380
# Epoch 194/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7692 - accuracy: 0.4223 - val_loss: 1.9809 - val_accuracy: 0.4780
# Epoch 195/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7467 - accuracy: 0.4337 - val_loss: 2.0044 - val_accuracy: 0.4545
# Epoch 196/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7579 - accuracy: 0.4300 - val_loss: 1.9762 - val_accuracy: 0.4825
# Epoch 197/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7653 - accuracy: 0.4283 - val_loss: 1.9751 - val_accuracy: 0.4855
# Epoch 198/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7610 - accuracy: 0.4286 - val_loss: 1.9726 - val_accuracy: 0.4875
# Epoch 199/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7528 - accuracy: 0.4366 - val_loss: 1.9921 - val_accuracy: 0.4680
# Epoch 200/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7716 - accuracy: 0.4238 - val_loss: 1.9867 - val_accuracy: 0.4730
# Epoch 201/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7660 - accuracy: 0.4291 - val_loss: 1.9925 - val_accuracy: 0.4675
# Epoch 202/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7530 - accuracy: 0.4325 - val_loss: 1.9648 - val_accuracy: 0.4975
# Epoch 203/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7519 - accuracy: 0.4315 - val_loss: 1.9856 - val_accuracy: 0.4735
# Epoch 204/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7587 - accuracy: 0.4314 - val_loss: 1.9789 - val_accuracy: 0.4805
# Epoch 205/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7590 - accuracy: 0.4292 - val_loss: 1.9766 - val_accuracy: 0.4840
# Epoch 206/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7613 - accuracy: 0.4295 - val_loss: 1.9875 - val_accuracy: 0.4735
# Epoch 207/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7498 - accuracy: 0.4416 - val_loss: 2.0127 - val_accuracy: 0.4465
# Epoch 208/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7753 - accuracy: 0.4276 - val_loss: 2.0089 - val_accuracy: 0.4495
# Epoch 209/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7835 - accuracy: 0.4204 - val_loss: 1.9725 - val_accuracy: 0.4870
# Epoch 210/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7818 - accuracy: 0.4200 - val_loss: 1.9838 - val_accuracy: 0.4760
# Epoch 211/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7631 - accuracy: 0.4323 - val_loss: 1.9826 - val_accuracy: 0.4765
# Epoch 212/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7442 - accuracy: 0.4415 - val_loss: 2.0008 - val_accuracy: 0.4590
# Epoch 213/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7706 - accuracy: 0.4278 - val_loss: 1.9820 - val_accuracy: 0.4775
# Epoch 214/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7587 - accuracy: 0.4305 - val_loss: 1.9815 - val_accuracy: 0.4790
# Epoch 215/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7829 - accuracy: 0.4215 - val_loss: 1.9789 - val_accuracy: 0.4810
# Epoch 216/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7575 - accuracy: 0.4353 - val_loss: 1.9781 - val_accuracy: 0.4830
# Epoch 217/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7459 - accuracy: 0.4379 - val_loss: 1.9857 - val_accuracy: 0.4725
# Epoch 218/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7566 - accuracy: 0.4329 - val_loss: 1.9758 - val_accuracy: 0.4830
# Epoch 219/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7619 - accuracy: 0.4323 - val_loss: 1.9707 - val_accuracy: 0.4880
# Epoch 220/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7521 - accuracy: 0.4335 - val_loss: 1.9878 - val_accuracy: 0.4710
# Epoch 221/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7543 - accuracy: 0.4367 - val_loss: 1.9921 - val_accuracy: 0.4685
# Epoch 222/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7583 - accuracy: 0.4338 - val_loss: 1.9933 - val_accuracy: 0.4640
# Epoch 223/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7532 - accuracy: 0.4372 - val_loss: 1.9845 - val_accuracy: 0.4755
# Epoch 224/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7603 - accuracy: 0.4339 - val_loss: 1.9787 - val_accuracy: 0.4790
# Epoch 225/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7657 - accuracy: 0.4338 - val_loss: 2.0003 - val_accuracy: 0.4605
# Epoch 226/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7687 - accuracy: 0.4305 - val_loss: 1.9946 - val_accuracy: 0.4645
# Epoch 227/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7608 - accuracy: 0.4365 - val_loss: 1.9900 - val_accuracy: 0.4680
# Epoch 228/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7632 - accuracy: 0.4343 - val_loss: 2.0300 - val_accuracy: 0.4285
# Epoch 229/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7556 - accuracy: 0.4421 - val_loss: 1.9946 - val_accuracy: 0.4650
# Epoch 230/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7555 - accuracy: 0.4401 - val_loss: 1.9805 - val_accuracy: 0.4800
# Epoch 231/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7771 - accuracy: 0.4295 - val_loss: 1.9879 - val_accuracy: 0.4730
# Epoch 232/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7664 - accuracy: 0.4327 - val_loss: 1.9939 - val_accuracy: 0.4645
# Epoch 233/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7757 - accuracy: 0.4300 - val_loss: 1.9828 - val_accuracy: 0.4775
# Epoch 234/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7620 - accuracy: 0.4387 - val_loss: 1.9877 - val_accuracy: 0.4710
# Epoch 235/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7542 - accuracy: 0.4359 - val_loss: 2.0027 - val_accuracy: 0.4560
# Epoch 236/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7526 - accuracy: 0.4393 - val_loss: 2.0071 - val_accuracy: 0.4515
# Epoch 237/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7670 - accuracy: 0.4342 - val_loss: 1.9786 - val_accuracy: 0.4825
# Epoch 238/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7504 - accuracy: 0.4409 - val_loss: 1.9938 - val_accuracy: 0.4680
# Epoch 239/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7628 - accuracy: 0.4379 - val_loss: 1.9991 - val_accuracy: 0.4610
# Epoch 240/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7714 - accuracy: 0.4320 - val_loss: 1.9837 - val_accuracy: 0.4755
# Epoch 241/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7626 - accuracy: 0.4332 - val_loss: 1.9985 - val_accuracy: 0.4620
# Epoch 242/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7665 - accuracy: 0.4376 - val_loss: 2.0019 - val_accuracy: 0.4590
# Epoch 243/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7841 - accuracy: 0.4304 - val_loss: 1.9940 - val_accuracy: 0.4670
# Epoch 244/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7547 - accuracy: 0.4407 - val_loss: 1.9941 - val_accuracy: 0.4635
# Epoch 245/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7765 - accuracy: 0.4293 - val_loss: 1.9786 - val_accuracy: 0.4835
# Epoch 246/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7593 - accuracy: 0.4427 - val_loss: 1.9979 - val_accuracy: 0.4615
# Epoch 247/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7446 - accuracy: 0.4472 - val_loss: 2.0033 - val_accuracy: 0.4550
# Epoch 248/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7662 - accuracy: 0.4403 - val_loss: 1.9878 - val_accuracy: 0.4720
# Epoch 249/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7522 - accuracy: 0.4416 - val_loss: 1.9995 - val_accuracy: 0.4625
# Epoch 250/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7674 - accuracy: 0.4345 - val_loss: 1.9890 - val_accuracy: 0.4705
# Epoch 251/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7525 - accuracy: 0.4428 - val_loss: 1.9812 - val_accuracy: 0.4785
# Epoch 252/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7468 - accuracy: 0.4436 - val_loss: 1.9938 - val_accuracy: 0.4680
# Epoch 253/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7502 - accuracy: 0.4441 - val_loss: 2.0014 - val_accuracy: 0.4590
# Epoch 254/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7642 - accuracy: 0.4352 - val_loss: 2.0067 - val_accuracy: 0.4520
# Epoch 255/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7647 - accuracy: 0.4365 - val_loss: 1.9933 - val_accuracy: 0.4675
# Epoch 256/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7630 - accuracy: 0.4362 - val_loss: 2.0001 - val_accuracy: 0.4595
# Epoch 257/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7631 - accuracy: 0.4396 - val_loss: 1.9721 - val_accuracy: 0.4875
# Epoch 258/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7716 - accuracy: 0.4317 - val_loss: 1.9932 - val_accuracy: 0.4675
# Epoch 259/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7542 - accuracy: 0.4443 - val_loss: 2.0250 - val_accuracy: 0.4350
# Epoch 260/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7654 - accuracy: 0.4367 - val_loss: 1.9725 - val_accuracy: 0.4865
# Epoch 261/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7551 - accuracy: 0.4438 - val_loss: 1.9854 - val_accuracy: 0.4745
# Epoch 262/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7703 - accuracy: 0.4368 - val_loss: 1.9866 - val_accuracy: 0.4750
# Epoch 263/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7774 - accuracy: 0.4330 - val_loss: 1.9988 - val_accuracy: 0.4615
# Epoch 264/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7718 - accuracy: 0.4366 - val_loss: 1.9843 - val_accuracy: 0.4760
# Epoch 265/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7456 - accuracy: 0.4531 - val_loss: 1.9788 - val_accuracy: 0.4810
# Epoch 266/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7622 - accuracy: 0.4373 - val_loss: 1.9949 - val_accuracy: 0.4635
# Epoch 267/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7550 - accuracy: 0.4456 - val_loss: 2.0220 - val_accuracy: 0.4370
# Epoch 268/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7641 - accuracy: 0.4401 - val_loss: 1.9807 - val_accuracy: 0.4790
# Epoch 269/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7785 - accuracy: 0.4405 - val_loss: 2.0020 - val_accuracy: 0.4580
# Epoch 270/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7696 - accuracy: 0.4335 - val_loss: 1.9895 - val_accuracy: 0.4705
# Epoch 271/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7703 - accuracy: 0.4445 - val_loss: 1.9848 - val_accuracy: 0.4765
# Epoch 272/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7883 - accuracy: 0.4294 - val_loss: 1.9987 - val_accuracy: 0.4605
# Epoch 273/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7467 - accuracy: 0.4527 - val_loss: 1.9915 - val_accuracy: 0.4690
# Epoch 274/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7663 - accuracy: 0.4384 - val_loss: 2.0026 - val_accuracy: 0.4575
# Epoch 275/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7591 - accuracy: 0.4431 - val_loss: 1.9866 - val_accuracy: 0.4725
# Epoch 276/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7624 - accuracy: 0.4391 - val_loss: 1.9795 - val_accuracy: 0.4815
# Epoch 277/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7548 - accuracy: 0.4474 - val_loss: 1.9745 - val_accuracy: 0.4850
# Epoch 278/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7608 - accuracy: 0.4395 - val_loss: 1.9771 - val_accuracy: 0.4835
# Epoch 279/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7642 - accuracy: 0.4447 - val_loss: 1.9897 - val_accuracy: 0.4720
# Epoch 280/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7613 - accuracy: 0.4406 - val_loss: 1.9872 - val_accuracy: 0.4725
# Epoch 281/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7696 - accuracy: 0.4367 - val_loss: 1.9832 - val_accuracy: 0.4770
# Epoch 282/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7524 - accuracy: 0.4492 - val_loss: 1.9841 - val_accuracy: 0.4770
# Epoch 283/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7686 - accuracy: 0.4373 - val_loss: 1.9878 - val_accuracy: 0.4725
# Epoch 284/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7505 - accuracy: 0.4493 - val_loss: 1.9903 - val_accuracy: 0.4705
# Epoch 285/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7594 - accuracy: 0.4378 - val_loss: 1.9842 - val_accuracy: 0.4755
# Epoch 286/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7775 - accuracy: 0.4364 - val_loss: 1.9954 - val_accuracy: 0.4645
# Epoch 287/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7751 - accuracy: 0.4347 - val_loss: 1.9905 - val_accuracy: 0.4705
# Epoch 288/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7646 - accuracy: 0.4423 - val_loss: 2.0078 - val_accuracy: 0.4520
# Epoch 289/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7490 - accuracy: 0.4474 - val_loss: 2.0100 - val_accuracy: 0.4505
# Epoch 290/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7484 - accuracy: 0.4476 - val_loss: 2.0019 - val_accuracy: 0.4570
# Epoch 291/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7588 - accuracy: 0.4442 - val_loss: 2.0070 - val_accuracy: 0.4525
# Epoch 292/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7687 - accuracy: 0.4373 - val_loss: 1.9901 - val_accuracy: 0.4710
# Epoch 293/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7515 - accuracy: 0.4456 - val_loss: 1.9955 - val_accuracy: 0.4645
# Epoch 294/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7653 - accuracy: 0.4360 - val_loss: 2.0032 - val_accuracy: 0.4555
# Epoch 295/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7473 - accuracy: 0.4479 - val_loss: 1.9902 - val_accuracy: 0.4695
# Epoch 296/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7473 - accuracy: 0.4505 - val_loss: 1.9893 - val_accuracy: 0.4720
# Epoch 297/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7613 - accuracy: 0.4378 - val_loss: 1.9847 - val_accuracy: 0.4755
# Epoch 298/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7743 - accuracy: 0.4316 - val_loss: 1.9892 - val_accuracy: 0.4710
# Epoch 299/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7492 - accuracy: 0.4535 - val_loss: 2.0018 - val_accuracy: 0.4585
# Epoch 300/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7540 - accuracy: 0.4468 - val_loss: 1.9844 - val_accuracy: 0.4775
# Epoch 301/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7653 - accuracy: 0.4398 - val_loss: 2.0000 - val_accuracy: 0.4610
# Epoch 302/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7670 - accuracy: 0.4399 - val_loss: 1.9929 - val_accuracy: 0.4665
# Epoch 303/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7572 - accuracy: 0.4462 - val_loss: 1.9757 - val_accuracy: 0.4850
# Epoch 304/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7579 - accuracy: 0.4438 - val_loss: 1.9939 - val_accuracy: 0.4655
# Epoch 305/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7551 - accuracy: 0.4461 - val_loss: 2.0123 - val_accuracy: 0.4470
# Epoch 306/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7563 - accuracy: 0.4471 - val_loss: 1.9777 - val_accuracy: 0.4830
# Epoch 307/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7687 - accuracy: 0.4385 - val_loss: 1.9782 - val_accuracy: 0.4815
# Epoch 308/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7558 - accuracy: 0.4506 - val_loss: 1.9944 - val_accuracy: 0.4655
# Epoch 309/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7607 - accuracy: 0.4421 - val_loss: 1.9897 - val_accuracy: 0.4700
# Epoch 310/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7746 - accuracy: 0.4368 - val_loss: 1.9770 - val_accuracy: 0.4820
# Epoch 311/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7675 - accuracy: 0.4325 - val_loss: 1.9804 - val_accuracy: 0.4810
# Epoch 312/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7516 - accuracy: 0.4435 - val_loss: 1.9896 - val_accuracy: 0.4720
# Epoch 313/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7542 - accuracy: 0.4468 - val_loss: 2.0173 - val_accuracy: 0.4420
# Epoch 314/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7716 - accuracy: 0.4371 - val_loss: 1.9865 - val_accuracy: 0.4745
# Epoch 315/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7518 - accuracy: 0.4501 - val_loss: 2.0003 - val_accuracy: 0.4600
# Epoch 316/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7683 - accuracy: 0.4422 - val_loss: 1.9818 - val_accuracy: 0.4765
# Epoch 317/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7612 - accuracy: 0.4476 - val_loss: 1.9954 - val_accuracy: 0.4655
# Epoch 318/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7698 - accuracy: 0.4426 - val_loss: 1.9897 - val_accuracy: 0.4710
# Epoch 319/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7600 - accuracy: 0.4469 - val_loss: 1.9787 - val_accuracy: 0.4825
# Epoch 320/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7706 - accuracy: 0.4412 - val_loss: 2.0069 - val_accuracy: 0.4530
# Epoch 321/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7720 - accuracy: 0.4371 - val_loss: 1.9982 - val_accuracy: 0.4625
# Epoch 322/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7682 - accuracy: 0.4450 - val_loss: 2.0137 - val_accuracy: 0.4440
# Epoch 323/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7631 - accuracy: 0.4447 - val_loss: 1.9926 - val_accuracy: 0.4690
# Epoch 324/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7770 - accuracy: 0.4383 - val_loss: 2.0186 - val_accuracy: 0.4430
# Epoch 325/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7796 - accuracy: 0.4364 - val_loss: 1.9987 - val_accuracy: 0.4610
# Epoch 326/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8022 - accuracy: 0.4244 - val_loss: 1.9975 - val_accuracy: 0.4635
# Epoch 327/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7745 - accuracy: 0.4426 - val_loss: 2.0171 - val_accuracy: 0.4430
# Epoch 328/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7543 - accuracy: 0.4522 - val_loss: 1.9694 - val_accuracy: 0.4905
# Epoch 329/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7488 - accuracy: 0.4472 - val_loss: 1.9756 - val_accuracy: 0.4845
# Epoch 330/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7777 - accuracy: 0.4361 - val_loss: 2.0023 - val_accuracy: 0.4565
# Epoch 331/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7744 - accuracy: 0.4401 - val_loss: 1.9753 - val_accuracy: 0.4845
# Epoch 332/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7705 - accuracy: 0.4463 - val_loss: 1.9839 - val_accuracy: 0.4760
# Epoch 333/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7769 - accuracy: 0.4372 - val_loss: 1.9925 - val_accuracy: 0.4675
# Epoch 334/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7728 - accuracy: 0.4394 - val_loss: 2.0012 - val_accuracy: 0.4595
# ...
# Epoch 891/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7166 - accuracy: 0.7446 - val_loss: 1.9931 - val_accuracy: 0.4680
# Epoch 892/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6931 - accuracy: 0.7679 - val_loss: 1.9860 - val_accuracy: 0.4745
# Epoch 893/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6808 - accuracy: 0.7802 - val_loss: 1.9872 - val_accuracy: 0.4740
# Epoch 894/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6881 - accuracy: 0.7731 - val_loss: 1.9849 - val_accuracy: 0.4760
# Epoch 895/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6953 - accuracy: 0.7657 - val_loss: 2.0004 - val_accuracy: 0.4605
# Epoch 896/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7084 - accuracy: 0.7528 - val_loss: 2.0225 - val_accuracy: 0.4385
# Epoch 897/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7295 - accuracy: 0.7316 - val_loss: 2.0003 - val_accuracy: 0.4610
# Epoch 898/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7002 - accuracy: 0.7607 - val_loss: 1.9871 - val_accuracy: 0.4740
# Epoch 899/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6876 - accuracy: 0.7736 - val_loss: 1.9968 - val_accuracy: 0.4640
# Epoch 900/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6735 - accuracy: 0.7876 - val_loss: 1.9903 - val_accuracy: 0.4705
# Epoch 901/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7015 - accuracy: 0.7596 - val_loss: 1.9984 - val_accuracy: 0.4625
# Epoch 902/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7192 - accuracy: 0.7417 - val_loss: 1.9967 - val_accuracy: 0.4650
# Epoch 903/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6884 - accuracy: 0.7726 - val_loss: 2.0043 - val_accuracy: 0.4565
# Epoch 904/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6897 - accuracy: 0.7714 - val_loss: 2.0028 - val_accuracy: 0.4585
# Epoch 905/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7192 - accuracy: 0.7419 - val_loss: 1.9999 - val_accuracy: 0.4610
# Epoch 906/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6886 - accuracy: 0.7726 - val_loss: 1.9915 - val_accuracy: 0.4695
# Epoch 907/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6783 - accuracy: 0.7826 - val_loss: 2.0135 - val_accuracy: 0.4475
# Epoch 908/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6839 - accuracy: 0.7773 - val_loss: 2.0077 - val_accuracy: 0.4535
# Epoch 909/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6726 - accuracy: 0.7885 - val_loss: 1.9808 - val_accuracy: 0.4800
# Epoch 910/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6749 - accuracy: 0.7862 - val_loss: 1.9680 - val_accuracy: 0.4930
# Epoch 911/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6987 - accuracy: 0.7623 - val_loss: 1.9900 - val_accuracy: 0.4715
# Epoch 912/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7110 - accuracy: 0.7501 - val_loss: 1.9859 - val_accuracy: 0.4755
# Epoch 913/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7178 - accuracy: 0.7433 - val_loss: 2.0060 - val_accuracy: 0.4550
# Epoch 914/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7231 - accuracy: 0.7378 - val_loss: 2.0095 - val_accuracy: 0.4515
# Epoch 915/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7422 - accuracy: 0.7190 - val_loss: 2.0006 - val_accuracy: 0.4605
# Epoch 916/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7199 - accuracy: 0.7413 - val_loss: 2.0097 - val_accuracy: 0.4510
# Epoch 917/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7565 - accuracy: 0.7046 - val_loss: 2.0053 - val_accuracy: 0.4555
# Epoch 918/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7088 - accuracy: 0.7523 - val_loss: 1.9856 - val_accuracy: 0.4755
# Epoch 919/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6880 - accuracy: 0.7730 - val_loss: 1.9995 - val_accuracy: 0.4615
# Epoch 920/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7036 - accuracy: 0.7575 - val_loss: 2.0131 - val_accuracy: 0.4480
# Epoch 921/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6906 - accuracy: 0.7706 - val_loss: 1.9884 - val_accuracy: 0.4725
# Epoch 922/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7085 - accuracy: 0.7526 - val_loss: 2.0010 - val_accuracy: 0.4600
# Epoch 923/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7059 - accuracy: 0.7554 - val_loss: 1.9944 - val_accuracy: 0.4665
# Epoch 924/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7048 - accuracy: 0.7564 - val_loss: 2.0173 - val_accuracy: 0.4440
# Epoch 925/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6863 - accuracy: 0.7748 - val_loss: 1.9794 - val_accuracy: 0.4815
# Epoch 926/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7008 - accuracy: 0.7601 - val_loss: 2.0097 - val_accuracy: 0.4515
# Epoch 927/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7016 - accuracy: 0.7592 - val_loss: 2.0161 - val_accuracy: 0.4450
# Epoch 928/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6868 - accuracy: 0.7743 - val_loss: 1.9974 - val_accuracy: 0.4640
# Epoch 929/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7013 - accuracy: 0.7598 - val_loss: 2.0071 - val_accuracy: 0.4540
# Epoch 930/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6997 - accuracy: 0.7614 - val_loss: 2.0027 - val_accuracy: 0.4580
# Epoch 931/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6764 - accuracy: 0.7848 - val_loss: 1.9880 - val_accuracy: 0.4730
# Epoch 932/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6800 - accuracy: 0.7812 - val_loss: 1.9890 - val_accuracy: 0.4720
# Epoch 933/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6863 - accuracy: 0.7748 - val_loss: 2.0083 - val_accuracy: 0.4530
# Epoch 934/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6999 - accuracy: 0.7612 - val_loss: 1.9915 - val_accuracy: 0.4695
# Epoch 935/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6771 - accuracy: 0.7839 - val_loss: 2.0072 - val_accuracy: 0.4535
# Epoch 936/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6952 - accuracy: 0.7660 - val_loss: 1.9808 - val_accuracy: 0.4805
# Epoch 937/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7213 - accuracy: 0.7397 - val_loss: 2.0241 - val_accuracy: 0.4370
# Epoch 938/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7162 - accuracy: 0.7446 - val_loss: 1.9819 - val_accuracy: 0.4790
# Epoch 939/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7106 - accuracy: 0.7506 - val_loss: 2.0143 - val_accuracy: 0.4465
# Epoch 940/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7329 - accuracy: 0.7282 - val_loss: 2.0036 - val_accuracy: 0.4575
# Epoch 941/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7281 - accuracy: 0.7329 - val_loss: 1.9872 - val_accuracy: 0.4740
# Epoch 942/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7012 - accuracy: 0.7599 - val_loss: 1.9897 - val_accuracy: 0.4705
# Epoch 943/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7092 - accuracy: 0.7519 - val_loss: 2.0062 - val_accuracy: 0.4545
# Epoch 944/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7123 - accuracy: 0.7490 - val_loss: 2.0062 - val_accuracy: 0.4550
# Epoch 945/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6872 - accuracy: 0.7739 - val_loss: 1.9741 - val_accuracy: 0.4870
# Epoch 946/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7036 - accuracy: 0.7576 - val_loss: 1.9972 - val_accuracy: 0.4635
# Epoch 947/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6988 - accuracy: 0.7623 - val_loss: 1.9831 - val_accuracy: 0.4780
# Epoch 948/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6869 - accuracy: 0.7742 - val_loss: 1.9929 - val_accuracy: 0.4680
# Epoch 949/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6759 - accuracy: 0.7851 - val_loss: 1.9831 - val_accuracy: 0.4780
# Epoch 950/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.7049 - accuracy: 0.7561 - val_loss: 1.9817 - val_accuracy: 0.4795
# Epoch 951/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6872 - accuracy: 0.7737 - val_loss: 1.9800 - val_accuracy: 0.4810
# Epoch 952/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7085 - accuracy: 0.7524 - val_loss: 1.9972 - val_accuracy: 0.4640
# Epoch 953/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7093 - accuracy: 0.7518 - val_loss: 1.9888 - val_accuracy: 0.4725
# Epoch 954/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7141 - accuracy: 0.7471 - val_loss: 1.9889 - val_accuracy: 0.4720
# Epoch 955/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7086 - accuracy: 0.7526 - val_loss: 1.9832 - val_accuracy: 0.4775
# Epoch 956/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6785 - accuracy: 0.7825 - val_loss: 1.9810 - val_accuracy: 0.4805
# Epoch 957/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6695 - accuracy: 0.7915 - val_loss: 1.9902 - val_accuracy: 0.4705
# Epoch 958/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6925 - accuracy: 0.7685 - val_loss: 1.9723 - val_accuracy: 0.4890
# Epoch 959/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6820 - accuracy: 0.7791 - val_loss: 1.9759 - val_accuracy: 0.4850
# Epoch 960/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6786 - accuracy: 0.7823 - val_loss: 1.9937 - val_accuracy: 0.4680
# Epoch 961/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6903 - accuracy: 0.7709 - val_loss: 1.9808 - val_accuracy: 0.4805
# Epoch 962/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6993 - accuracy: 0.7619 - val_loss: 1.9973 - val_accuracy: 0.4635
# Epoch 963/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7003 - accuracy: 0.7608 - val_loss: 2.0170 - val_accuracy: 0.4440
# Epoch 964/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6910 - accuracy: 0.7702 - val_loss: 1.9905 - val_accuracy: 0.4710
# Epoch 965/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6707 - accuracy: 0.7902 - val_loss: 1.9967 - val_accuracy: 0.4645
# Epoch 966/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6899 - accuracy: 0.7713 - val_loss: 2.0027 - val_accuracy: 0.4585
# Epoch 967/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6836 - accuracy: 0.7776 - val_loss: 1.9908 - val_accuracy: 0.4695
# Epoch 968/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6970 - accuracy: 0.7642 - val_loss: 1.9817 - val_accuracy: 0.4795
# Epoch 969/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6839 - accuracy: 0.7772 - val_loss: 1.9870 - val_accuracy: 0.4740
# Epoch 970/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6791 - accuracy: 0.7820 - val_loss: 2.0112 - val_accuracy: 0.4500
# Epoch 971/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6983 - accuracy: 0.7629 - val_loss: 2.0021 - val_accuracy: 0.4590
# Epoch 972/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6856 - accuracy: 0.7754 - val_loss: 1.9905 - val_accuracy: 0.4705
# Epoch 973/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7023 - accuracy: 0.7587 - val_loss: 2.0059 - val_accuracy: 0.4550
# Epoch 974/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6989 - accuracy: 0.7622 - val_loss: 1.9943 - val_accuracy: 0.4670
# Epoch 975/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6857 - accuracy: 0.7752 - val_loss: 1.9963 - val_accuracy: 0.4650
# Epoch 976/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6972 - accuracy: 0.7639 - val_loss: 2.0430 - val_accuracy: 0.4180
# Epoch 977/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7072 - accuracy: 0.7538 - val_loss: 1.9899 - val_accuracy: 0.4710
# Epoch 978/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7111 - accuracy: 0.7499 - val_loss: 2.0171 - val_accuracy: 0.4445
# Epoch 979/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7089 - accuracy: 0.7523 - val_loss: 2.0104 - val_accuracy: 0.4510
# Epoch 980/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7170 - accuracy: 0.7440 - val_loss: 2.0344 - val_accuracy: 0.4265
# Epoch 981/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6983 - accuracy: 0.7627 - val_loss: 1.9936 - val_accuracy: 0.4675
# Epoch 982/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6897 - accuracy: 0.7713 - val_loss: 1.9885 - val_accuracy: 0.4725
# Epoch 983/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6722 - accuracy: 0.7889 - val_loss: 1.9868 - val_accuracy: 0.4740
# Epoch 984/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6860 - accuracy: 0.7751 - val_loss: 2.0051 - val_accuracy: 0.4560
# Epoch 985/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6870 - accuracy: 0.7740 - val_loss: 1.9898 - val_accuracy: 0.4710
# Epoch 986/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6721 - accuracy: 0.7891 - val_loss: 2.0114 - val_accuracy: 0.4500
# Epoch 987/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6840 - accuracy: 0.7772 - val_loss: 1.9947 - val_accuracy: 0.4665
# Epoch 988/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7087 - accuracy: 0.7524 - val_loss: 1.9957 - val_accuracy: 0.4650
# Epoch 989/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6869 - accuracy: 0.7744 - val_loss: 1.9839 - val_accuracy: 0.4770
# Epoch 990/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7210 - accuracy: 0.7400 - val_loss: 2.0020 - val_accuracy: 0.4590
# Epoch 991/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7205 - accuracy: 0.7404 - val_loss: 2.0090 - val_accuracy: 0.4520
# Epoch 992/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6865 - accuracy: 0.7748 - val_loss: 2.0030 - val_accuracy: 0.4580
# Epoch 993/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6825 - accuracy: 0.7786 - val_loss: 1.9949 - val_accuracy: 0.4660
# Epoch 994/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7197 - accuracy: 0.7414 - val_loss: 2.0042 - val_accuracy: 0.4570
# Epoch 995/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7261 - accuracy: 0.7350 - val_loss: 2.0082 - val_accuracy: 0.4530
# Epoch 996/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7232 - accuracy: 0.7380 - val_loss: 1.9952 - val_accuracy: 0.4660
# Epoch 997/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7662 - accuracy: 0.6950 - val_loss: 2.0137 - val_accuracy: 0.4475
# Epoch 998/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7235 - accuracy: 0.7376 - val_loss: 2.0052 - val_accuracy: 0.4560
# Epoch 999/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7162 - accuracy: 0.7450 - val_loss: 2.0025 - val_accuracy: 0.4585
# Epoch 1000/1000
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7234 - accuracy: 0.7376 - val_loss: 2.0020 - val_accuracy: 0.4590
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Output/models/30_80_RMSprop_no_dropout/assets

# %%
# Retrieve previously saved DROPOUT instanced variables w/ pickle rick
infile = open(f'/content/gdrive/My Drive/Colab Output/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_variables', 'rb')
retrieved_variables_dropout = pickle.load(infile)
infile.close()

# Retrieve previously saved NO DROPOUT instanced variables w/ pickle rick
infile = open(f'/content/gdrive/My Drive/Colab Output/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_variables', 'rb')
retrieved_variables_no_dropout = pickle.load(infile)
infile.close()

# Load retrieved variables into instance variables for plotting
train_loss_dropout, val_loss_dropout, train_acc_dropout, val_acc_dropout = retrieved_variables_dropout
train_loss_no_dropout, val_loss_no_dropout, train_acc_no_dropout, val_acc_no_dropout = retrieved_variables_no_dropout

# %%
for each in dropout_list:
    
    use_dropout = each
    
    if (use_dropout == True):
        # using dropout
        # Save the plot for loss
        plt.plot(range(1, len(train_loss_dropout) + 1), train_loss_dropout, label='Train')
        plt.plot(range(1, len(val_loss_dropout) + 1), val_loss_dropout, label='Test')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend()
        plt.title(f'{optimizer_} Model Loss with dropout')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_loss.pdf')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_loss.png')
        plt.close()
        # Save the plot for accuracy (with dropout)
        plt.plot(range(1, len(train_acc_dropout) + 1), train_acc_dropout, label='Train')
        plt.plot(range(1, len(val_acc_dropout) + 1), val_acc_dropout, label='Test')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend()
        plt.title(f'{optimizer_} Model Accuracy with dropout')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_accuracy.pdf')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_accuracy.png')
        plt.close()
    else:
        # no dropout
        # Save the plot for loss
        plt.plot(range(1, len(train_loss_no_dropout) + 1), train_loss_no_dropout, label='Train')
        plt.plot(range(1, len(val_loss_no_dropout) + 1), val_loss_no_dropout, label='Test')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend()
        plt.title(f'{optimizer_} Model Loss no dropout')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_loss.pdf')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_loss.png')
        plt.close()
        # Save the plot for accuracy (with dropout)
        plt.plot(range(1, len(train_acc_no_dropout) + 1), train_acc_no_dropout, label='Train')
        plt.plot(range(1, len(val_acc_no_dropout) + 1), val_acc_no_dropout, label='Test')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend()
        plt.title(f'{optimizer_} Model Accuracy no dropout')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_accuracy.pdf')
        plt.savefig(f'/content/gdrive/My Drive/Colab Output/results/part_a_{question}_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_accuracy.png')
        plt.close()
